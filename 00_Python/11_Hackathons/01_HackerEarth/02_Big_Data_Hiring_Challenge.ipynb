# %%
def solve (N, A, K):
    x = []
    for i in A:
        for j in A:
            x.append(abs(i-j))
    return sorted(x)[K-1]

# %%
solve(3,[4,3,1],6)
# Out:
# 2

# %%
sample = tuple("PYTHON")
sample[1]
# Out:
# 'Y'

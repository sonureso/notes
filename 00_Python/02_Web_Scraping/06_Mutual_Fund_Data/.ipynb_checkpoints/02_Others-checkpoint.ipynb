# %% [markdown]
# # 01. Important Links

# %%
d = {}
d['w2'] = "https://www1.nseindia.com/live_market/dynaContent/live_watch/get_quote/getHistoricalData.jsp?symbol=RELIANCE&series=EQ&fromDate=undefined&toDate=undefined&datePeriod=2weeks"
d['m3'] = "https://www1.nseindia.com/live_market/dynaContent/live_watch/get_quote/getHistoricalData.jsp?symbol=RELIANCE&series=EQ&fromDate=undefined&toDate=undefined&datePeriod=3months"
d['nse'] = "https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=Reliance&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2020&toDate=30-12-2020&dataType=PRICEVOLUMEDELIVERABLE"
d['reliance_info'] = "https://priceapi.moneycontrol.com/pricefeed/bse/equitycash/RI"
d['infy'] = "https://priceapi.moneycontrol.com/techCharts/techChartController/history?symbol=INFY&resolution=60&from=1617133838&to=1625395067"
d['infy_15m'] = "https://priceapi.moneycontrol.com/techCharts/techChartController/history?symbol=INFY&resolution=1D&from=1591267101&to=1625395161"
d['infy_max'] = "https://priceapi.moneycontrol.com/techCharts/techChartController/history?symbol=INFY&resolution=1D&from=-29934192031&to=1585711799"
d['infy_1d'] = "https://priceapi.moneycontrol.com/techCharts/techChartController/history?symbol=INFY&resolution=1&from=1625302231&to=1625395337"
d['infy_1d'] = "https://priceapi.moneycontrol.com/techCharts/techChartController/history?symbol=INFY&resolution=1&from=1625042515&to=1625215092"

# %%
d['nse']
# Out:
# 'https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=Reliance&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2020&toDate=30-12-2020&dataType=PRICEVOLUMEDELIVERABLE'

# %%
name = "Reliance"
start = "01-01-2021"
end = "02-06-2021"
path = "https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol="+name
path = path+"&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate="+start
path = path+"&toDate="+end+"&dataType=PRICEVOLUMEDELIVERABLE"
path
# Out:
# 'https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=Reliance&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2021&toDate=02-06-2021&dataType=PRICEVOLUMEDELIVERABLE'

# %%
path2 = "https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=Reliance&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2021&toDate=02-07-2021&dataType=PRICEVOLUMEDELIVERABLE"
print(path2)
path3="https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=Reliance&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2021&toDate=02-06-2021&dataType=PRICEVOLUMEDELIVERABLE"
# Out:
# https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=Reliance&segmentLink=3&symbolCount=2&series=EQ&dateRange=+&fromDate=01-01-2021&toDate=02-07-2021&dataType=PRICEVOLUMEDELIVERABLE

# %%
path==path3
# Out:
# True

# %% [markdown]
# # 01. Functions

# %%
from datetime import datetime
from urllib.request import Request, urlopen
import json
import pandas as pd

def get_t_stamp(date):
    try:
        return int(datetime.timestamp(datetime.strptime(date,'%d-%m-%Y')))
    except Exception as e:
        print("get_t_stamp: Exception occured :-",str(e))
        return 1

def bring_data(url):
    try:
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        client = urlopen(req)
        webpage = client.read()
        client.close()
        return webpage
    except Exception as e:
        print("bring_data: Exception occurred:-",str(e))
        return 1

def get_data(symbol,st,et,r):
    if(st!=1 and et!=1 and (r=="1D" or r=="1")):
        url="https://priceapi.moneycontrol.com/techCharts/techChartController/history?symbol="
        url=url+symbol+"&resolution="+r+"&from="+str(st)+"&to="+str(et)
        return bring_data(url)
    else:
        return 1
    
def process_data(page):
    try:
        data = json.loads(page)
        d = pd.DataFrame()
        d["date"] = [datetime.fromtimestamp(int(t)).date() for t in data['t']]
        d["time"] = [datetime.fromtimestamp(int(t)).time() for t in data['t']]
        d["open"] = data['o']
        d["close"] = data['c']
        d["high"] = data['h']
        d["low"] = data['l']
        d["volume"] = data['v']
        return d
    except Exception as e:
        print("process_data: Exception Occured:- ",str(e))
        return 1

# %% [markdown]
# # 02. Implementation

# %%
# Prepare Parameters: ['INFY','CDSL','']
st = get_t_stamp('25-05-2021')
et = get_t_stamp('02-07-2021')
r = "1D"
symbol = "CDSL"

# %%
# Bring data:
page = get_data(symbol,st,et,r)
page
# Out:
# b'{"s":"ok","t":[1621987200,1622073600,1622160000,1622419200,1622505600,1622592000,1622678400,1622764800,1623024000,1623110400,1623196800,1623283200,1623369600,1623628800,1623715200,1623801600,1623888000,1623974400,1624233600,1624320000,1624406400,1624492800,1624579200,1624838400,1624924800,1625011200,1625097600,1625184000],"o":[890.75,889.9,898.95,995.0,989.9,965.0,975.9,971.5,973.6,991.0,984.0,975.0,976.9,979.5,1001.0,1007.55,1005.0,997.45,971.0,1005.0,979.7,978.9,964.9,980.0,998.0,990.95,983.35,987.7],"h":[899.55,899.0,986.9,1008.7,994.8,982.5,976.8,990.25,998.35,992.45,990.15,984.0,985.65,995.7,1029.95,1020.0,1007.0,999.0,998.5,1005.0,983.65,978.95,976.0,997.5,998.0,990.95,995.0,1058.9],"l":[884.0,883.2,895.05,978.95,945.0,958.1,960.0,961.3,973.6,970.25,962.0,963.05,964.85,955.0,1000.1,1002.0,987.3,950.05,962.3,916.15,968.0,959.0,964.0,971.5,981.7,974.0,975.0,980.5],"c":[887.6,892.6,971.65,989.65,965.35,971.35,967.0,973.55,986.0,981.4,970.8,974.65,975.7,985.95,1007.55,1009.65,990.5,984.9,993.75,967.45,972.95,964.5,971.9,992.3,985.05,978.55,981.9,1034.75],"v":[504122,394531,3098824,1502962,967778,542388,427850,705654,501354,354800,508328,384473,346796,451943,1338978,400687,463080,784655,366552,4072619,393617,230857,217596,406648,313177,241651,294473,2064331]}'

# %%
# Process Data
d = process_data(page)
print(d)
# Out:
#           date      time     open    close     high      low   volume
# 0   2021-05-26  05:30:00   890.75   887.60   899.55   884.00   504122
# 1   2021-05-27  05:30:00   889.90   892.60   899.00   883.20   394531
# 2   2021-05-28  05:30:00   898.95   971.65   986.90   895.05  3098824
# 3   2021-05-31  05:30:00   995.00   989.65  1008.70   978.95  1502962
# 4   2021-06-01  05:30:00   989.90   965.35   994.80   945.00   967778
# 5   2021-06-02  05:30:00   965.00   971.35   982.50   958.10   542388
# 6   2021-06-03  05:30:00   975.90   967.00   976.80   960.00   427850
# 7   2021-06-04  05:30:00   971.50   973.55   990.25   961.30   705654
# 8   2021-06-07  05:30:00   973.60   986.00   998.35   973.60   501354
# 9   2021-06-08  05:30:00   991.00   981.40   992.45   970.25   354800
# 10  2021-06-09  05:30:00   984.00   970.80   990.15   962.00   508328
# 11  2021-06-10  05:30:00   975.00   974.65   984.00   963.05   384473
# 12  2021-06-11  05:30:00   976.90   975.70   985.65   964.85   346796
# 13  2021-06-14  05:30:00   979.50   985.95   995.70   955.00   451943
# 14  2021-06-15  05:30:00  1001.00  1007.55  1029.95  1000.10  1338978
# 15  2021-06-16  05:30:00  1007.55  1009.65  1020.00  1002.00   400687
# 16  2021-06-17  05:30:00  1005.00   990.50  1007.00   987.30   463080
# 17  2021-06-18  05:30:00   997.45   984.90   999.00   950.05   784655
# 18  2021-06-21  05:30:00   971.00   993.75   998.50   962.30   366552
# 19  2021-06-22  05:30:00  1005.00   967.45  1005.00   916.15  4072619
# 20  2021-06-23  05:30:00   979.70   972.95   983.65   968.00   393617
# 21  2021-06-24  05:30:00   978.90   964.50   978.95   959.00   230857
# 22  2021-06-25  05:30:00   964.90   971.90   976.00   964.00   217596
# 23  2021-06-28  05:30:00   980.00   992.30   997.50   971.50   406648
# 24  2021-06-29  05:30:00   998.00   985.05   998.00   981.70   313177
# 25  2021-06-30  05:30:00   990.95   978.55   990.95   974.00   241651
# 26  2021-07-01  05:30:00   983.35   981.90   995.00   975.00   294473
# 27  2021-07-02  05:30:00   987.70  1034.75  1058.90   980.50  2064331
